# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim

import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.utils import save_image
from torchsummary import summary

from random import randint

from polynomial_nets import CP_L3

from poly_GAN import Generator_CP_L3, Critic_CP_L3, Generator_NCP_L3, Generator_CP_CT3, gradient_penalty, initialize_weights
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from torch.utils.data import random_split

import matplotlib.pyplot as plt
from torchvision.utils import make_grid
import pandas as pd
from torch.utils.tensorboard import SummaryWriter

#from Cuda import DeviceDataLoader

# %%
torch.cuda.empty_cache() 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LEARNING_RATE = 1e-4
BATCH_SIZE = 64
IMAGE_SIZE = 28
CHANNELS_IMG = 1
Z_DIM = 100
NUM_EPOCHS = 5
FEATURES_DISC = 28
FEATURES_GEN = 28
CRITIC_ITERATIONS = 2
#WEIGHT_CLIP = 0.01
LAMBDA_GP = 10
RANK_CRITIC = 200
RANK_GEN = 300
LHP = 300

# %% [markdown]
# transforms = transforms.Compose(
#     [
#         transforms.Resize(IMAGE_SIZE),
#         transforms.ToTensor(),
#         transforms.Normalize(
#             [0.5 for _ in range(CHANNELS_IMG)], [0.5 for _ in range (CHANNELS_IMG)]),
#
#     ]
# )

# %%
dataset = datasets.MNIST(root='data/', train=True, transform=transforms.Compose([transforms.Resize(32), transforms.ToTensor()]))

# %%
loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
gen = Generator_CP_L3(Z_DIM, IMAGE_SIZE*IMAGE_SIZE, RANK_GEN).to(device)
#gen_C3 = Generator_CP_C3(Z_DIM, IMAGE_SIZE, RANK_GEN).to(device)
critic = Critic_CP_L3(IMAGE_SIZE*IMAGE_SIZE, RANK_CRITIC).to(device)
initialize_weights(gen)
initialize_weights(critic)

# %%
gen_CT3 = Generator_CP_CT3(Z_DIM, 1, RANK_GEN).to(device)
input = torch.randn(2, Z_DIM, 1, 1).to(device)
out = gen_CT3(input)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 3
#       1 gen_CT3 = Generator_CP_CT3(Z_DIM, 1, RANK_GEN).to(device)
#       2 input = torch.randn(2, Z_DIM, 1, 1).to(device)
# ----> 3 out = gen_CT3(input)
#
# File ~/Softwares/miniconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Projects/Polynomial_Nets/poly_GAN.py:47, in Generator_CP_CT3.forward(self, z)
#      46 def forward(self, z):
# ---> 47   return  self.gen(z)
#
# File ~/Softwares/miniconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Softwares/miniconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~/Softwares/miniconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Projects/Polynomial_Nets/polynomial_nets.py:61, in CP_CT3.forward(self, z)
#      59 x1 = self.layer_U1(z)
#      60 x2 = self.layer_U2(z) * x1 + x1
# ---> 61 x3 = self.layer_U3(z) * x2 + x2
#      62 x = self.layer_C(x3)
#      63 return x
#
# RuntimeError: The size of tensor a (3) must match the size of tensor b (2) at non-singleton dimension 3

# %%
opt_gen = optim.Adam(gen.parameters(), lr=LEARNING_RATE, betas=(0.0, 0.9))
opt_critic = optim.Adam(critic.parameters(), lr=LEARNING_RATE, betas=(0.0, 0.9))

# %%
#criterion = nn.BCELoss()
for epoch in range(NUM_EPOCHS):
    for batch_idx, (real, _) in enumerate(loader):
        real = real.reshape(-1, IMAGE_SIZE*IMAGE_SIZE) 
        real = real.to(device)


        for _ in range(CRITIC_ITERATIONS):
            noise = torch.randn((real.shape[0], Z_DIM)).to(device)
            #noise_C3 = torch.randn((real.shape[0], Z_DIM, 1, 1)).to(device)
            fake = gen(noise)
            #fake_C3 = gen(noise_C3)
            #fake = fake_C3.reshape(-1, IMAGE_SIZE*IMAGE_SIZE) 
            critic_real = critic(real).reshape(-1)
            critic_fake = critic(fake).reshape(-1)
            gp = gradient_penalty(critic, real, fake, device=device)
            loss_critic = (
                -(torch.mean(critic_real) - torch.mean(critic_fake)) + LAMBDA_GP*gp
            )
            critic.zero_grad()
            loss_critic.backward(retain_graph=True)
            opt_critic.step()

            #for p in critic.parameters():
                #p.data.clamp_(-WEIGHT_CLIP, WEIGHT_CLIP)

        ### Train Generator: min -E[critic(gen_fake)]
        output = critic(fake).reshape(-1)
        loss_gen = -torch.mean(output)
        gen.zero_grad()
        loss_gen.backward()
        opt_gen.step()


    print(f"Epoch [{epoch + 1}/{NUM_EPOCHS}]  \ Loss D: {loss_critic: .4f}, loss G: {loss_gen: .4f}")
# Out:
# Epoch [1/5]  \ Loss D: -0.0612, loss G: -0.1989
# Epoch [2/5]  \ Loss D: -0.1148, loss G:  0.0233
# Epoch [3/5]  \ Loss D: -0.1326, loss G:  0.1214
# Epoch [4/5]  \ Loss D: -0.0336, loss G: -0.0478
# Epoch [5/5]  \ Loss D:  0.0410, loss G:  0.0261

# %%
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(images.detach()[:nmax], nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
input = torch.randn(64, Z_DIM).to(device)
fake = gen(input)

# %%
fake = fake.reshape(-1, 1, IMAGE_SIZE, IMAGE_SIZE).to('cpu')

# %%
show_images(fake)
