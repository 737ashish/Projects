# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.utils import save_image
from torchsummary import summary

from random import randint

from polynomial_nets import CP_L3, CP_L3_sparse

from poly_VAE import Flatten, UnFlatten, VAE_CP_L3, VAE_CP_L3_sparse, VAE_CP_L3_sparse_LU, loss_fn
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from torch.utils.data import random_split

import matplotlib.pyplot as plt
from torchvision.utils import make_grid
import pandas as pd

#from Cuda import DeviceDataLoader

# %%
torch.cuda.empty_cache() 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = 'cpu'
LEARNING_RATE = 1e-4
BATCH_SIZE = 64
IMAGE_SIZE = 28
CHANNELS_IMG = 1
Z_DIM = 100
NUM_EPOCHS = 5
IMAGE_CHANNELS = 1
RANK = 200
H_DIM = 200

# %%
# Download training dataset
dataset = MNIST(root='data/', download=True)
# MNIST dataset (images and labels)
dataset = MNIST(root='data/', train=True, transform=transforms.ToTensor())

# %%
train_ds, val_ds = random_split(dataset, [50000, 10000])

# %%
train_loader = DataLoader(train_ds, BATCH_SIZE, shuffle=True)
#train_loader = DeviceDataLoader(train_loader, device)
#val_loader = DataLoader(val_ds, BATCH_SIZE)

# %%
model = VAE_CP_L3_sparse_LU(IMAGE_SIZE*IMAGE_SIZE, H_DIM, Z_DIM, RANK).to(device)
#model = VAE_CP_L3_sparse(IMAGE_SIZE*IMAGE_SIZE, H_DIM, Z_DIM, RANK).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
#model = DeviceDataLoader(model, device)

# %%
list_of_losses = []
list_of_epochs = []
for epoch in range(NUM_EPOCHS):
    for images, _ in train_loader: 
        images = images.reshape(-1, IMAGE_SIZE*IMAGE_SIZE)   
        recon_images, mu, logvar = model(images.to(device))
        loss, bce, kld = loss_fn(recon_images.to(device), images.to(device), mu.to(device), logvar.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        #to_print = "Epoch[{}/{}] Loss: {:.3f} {:.3f} {:.3f}".format(epoch+1, 
                                #epochs, loss.data[0]/bs, bce.data[0]/bs, kld.data[0]/bs)
        #print(to_print)
    list_of_losses.append(loss)
    list_of_epochs.append(epoch + 1)
    print('loss', loss)
    print("Epoch : ", epoch + 1)
# Out:
# /home/ashish/Softwares/miniconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# loss tensor(24095.5781, grad_fn=<AddBackward0>)
# Epoch :  1
# loss tensor(5711.9004, grad_fn=<AddBackward0>)
# Epoch :  2
# loss tensor(2432.7402, grad_fn=<AddBackward0>)
# Epoch :  3
# loss tensor(1429.1311, grad_fn=<AddBackward0>)
# Epoch :  4
# loss tensor(1394.8674, grad_fn=<AddBackward0>)
# Epoch :  5

# %%
for images, _ in train_loader: 
    recon_images, mu, logvar = model(images.to(device))
    break

# %%
recon_images = recon_images.reshape(-1, 1, IMAGE_SIZE, IMAGE_SIZE)

# %%
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(images.detach()[:nmax], nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
show_images(images)

# %%
show_images(recon_images)

# %%
list_of_losses = [i.detach().numpy() for i in list_of_losses ]

# %%
my_dict = {
    "epochs": list_of_epochs, 
    "losses": list_of_losses
}

df = pd.DataFrame(my_dict)

# %%
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_3affe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3affe_level0_col0" class="col_heading level0 col0" >epochs</th>
#       <th id="T_3affe_level0_col1" class="col_heading level0 col1" >losses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3affe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3affe_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_3affe_row0_col1" class="data row0 col1" >24095.578</td>
#     </tr>
#     <tr>
#       <th id="T_3affe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3affe_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_3affe_row1_col1" class="data row1 col1" >5711.9004</td>
#     </tr>
#     <tr>
#       <th id="T_3affe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3affe_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_3affe_row2_col1" class="data row2 col1" >2432.7402</td>
#     </tr>
#     <tr>
#       <th id="T_3affe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3affe_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_3affe_row3_col1" class="data row3 col1" >1429.1311</td>
#     </tr>
#     <tr>
#       <th id="T_3affe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3affe_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_3affe_row4_col1" class="data row4 col1" >1394.8674</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_param = []
for name, param in model.named_parameters():
    num = torch.count_nonzero(param)
    num_param.append(num)

# %%
torch.sum(torch.tensor(num_param))
# Out:
# tensor(729184)

# %%
model.encoder.layer_U2
# Out:
# Parameter containing:
# tensor([[ 0.5705,  0.8833,  0.7150,  ..., -0.5657,  0.4926,  0.9898],
#         [ 0.0000, -1.8746, -0.4203,  ..., -1.6860,  0.3342, -0.3687],
#         [ 0.0000,  0.0000,  0.6757,  ...,  0.1672,  0.1938,  0.6094],
#         ...,
#         [ 0.0000,  0.0000,  0.0000,  ..., -1.3924,  0.6327,  0.4632],
#         [ 0.0000,  0.0000,  0.0000,  ...,  1.2460,  1.7737,  0.7549],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.8327,  0.0827, -0.9540]],
#        requires_grad=True)

# %%
torch.count_nonzero(model.encoder.layer_U2)
# Out:
# tensor(136900)

# %%
torch.numel(model.encoder.layer_U2)
# Out:
# 156800
