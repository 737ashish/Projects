# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.utils import save_image
from torchsummary import summary

from random import randint

from polynomial_nets import CP_L3

from poly_VAE import Flatten, UnFlatten, VAE_CP_L3, VAE_mlp, loss_fn
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from torch.utils.data import random_split

import matplotlib.pyplot as plt
from torchvision.utils import make_grid
import pandas as pd

#from Cuda import DeviceDataLoader

# %%
torch.cuda.empty_cache() 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = 'cpu'
LEARNING_RATE = 1e-4
BATCH_SIZE = 64
IMAGE_SIZE = 28
CHANNELS_IMG = 1
Z_DIM = 100
NUM_EPOCHS = 5
IMAGE_CHANNELS = 1
RANK = 100
H_DIM = 300

# %%
# Download training dataset
dataset = MNIST(root='data/', download=True)
# MNIST dataset (images and labels)
dataset = MNIST(root='data/', train=True, transform=transforms.ToTensor())

# %%
train_ds, val_ds = random_split(dataset, [50000, 10000])

# %%
train_loader = DataLoader(train_ds, BATCH_SIZE, shuffle=True)
#train_loader = DeviceDataLoader(train_loader, device)
#val_loader = DataLoader(val_ds, BATCH_SIZE)

# %%
model = VAE_mlp(IMAGE_SIZE*IMAGE_SIZE, H_DIM, Z_DIM).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
#model = DeviceDataLoader(model, device)

# %%
list_of_losses = []
list_of_epochs =[]
for epoch in range(NUM_EPOCHS):
    for images, _ in train_loader: 
        images = images.reshape(-1, IMAGE_SIZE*IMAGE_SIZE)   
        recon_images, mu, logvar = model(images.to(device))
        loss, bce, kld = loss_fn(recon_images.to(device), images.to(device), mu.to(device), logvar.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        #to_print = "Epoch[{}/{}] Loss: {:.3f} {:.3f} {:.3f}".format(epoch+1, 
                                #epochs, loss.data[0]/bs, bce.data[0]/bs, kld.data[0]/bs)
        #print(to_print)
    list_of_losses.append(loss)
    list_of_epochs.append(epoch + 1)
    print('loss', loss)
    print("Epoch : ", epoch + 1)
# Out:
# /home/ashish/Softwares/miniconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# loss tensor(2584.6765, grad_fn=<AddBackward0>)
# Epoch :  1
# loss tensor(2725.2859, grad_fn=<AddBackward0>)
# Epoch :  2
# loss tensor(2303.0676, grad_fn=<AddBackward0>)
# Epoch :  3
# loss tensor(1971.2054, grad_fn=<AddBackward0>)
# Epoch :  4
# loss tensor(2017.5034, grad_fn=<AddBackward0>)
# Epoch :  5

# %%
for images, _ in train_loader: 
      
    recon_images, mu, logvar = model(images.reshape(-1, IMAGE_SIZE*IMAGE_SIZE).to(device))
    break

# %%
recon_images = recon_images.reshape(-1, 1, IMAGE_SIZE, IMAGE_SIZE)

# %%
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(images.detach()[:nmax], nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
show_images(images)

# %%
show_images(recon_images)

# %%
list_of_losses = [i.detach().numpy() for i in list_of_losses ]

# %%
my_dict = {
    "epochs": list_of_epochs, 
    "losses": list_of_losses
}

df = pd.DataFrame(my_dict)

# %%
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_066b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_066b8_level0_col0" class="col_heading level0 col0" >epochs</th>
#       <th id="T_066b8_level0_col1" class="col_heading level0 col1" >losses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_066b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_066b8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_066b8_row0_col1" class="data row0 col1" >2584.6765</td>
#     </tr>
#     <tr>
#       <th id="T_066b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_066b8_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_066b8_row1_col1" class="data row1 col1" >2725.286</td>
#     </tr>
#     <tr>
#       <th id="T_066b8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_066b8_row2_col0" class="data row2 col0" >3</td>
# ...

# %%
model.parameters
# Out:
# <bound method Module.parameters of VAE_mlp(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=300, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=300, out_features=300, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=300, out_features=300, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=300, out_features=300, bias=True)
#     (7): ReLU()
#   )
#   (fc1): Linear(in_features=300, out_features=100, bias=True)
#   (fc2): Linear(in_features=300, out_features=100, bias=True)
#   (fc3): Linear(in_features=100, out_features=300, bias=True)
#   (decoder): Sequential(
#     (0): Linear(in_features=300, out_features=300, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=300, out_features=300, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=300, out_features=300, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=300, out_features=784, bias=True)
#     (7): Sigmoid()
#   )
# )>

# %%
num_param = []
for name, param in model.named_parameters():
    num = torch.numel(param)
    num_param.append(num)

# %%
num_p = torch.sum(torch.tensor(num_param))

# %%
time = 60 + 47

# %%
dict = {
    "Number of parameters": num_p.detach().numpy(), 
    "Training Time (s)": time
}

df1 = pd.DataFrame([dict])

# %%
df1.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_718c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_718c3_level0_col0" class="col_heading level0 col0" >Number of parameters</th>
#       <th id="T_718c3_level0_col1" class="col_heading level0 col1" >Training Time (s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_718c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_718c3_row0_col0" class="data row0 col0" >1103784</td>
#       <td id="T_718c3_row0_col1" class="data row0 col1" >107</td>
#     </tr>
#   </tbody>
# </table>
