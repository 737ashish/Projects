# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.utils import save_image
from torchsummary import summary

from random import randint

from polynomial_nets import CP_L3

from poly_VAE import Flatten, UnFlatten, VAE_CP_L3, loss_fn, VAE_Cheby_L3, VAE_Cheby3_kernel32, VAE_Cheby_L3_sparse
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from torch.utils.data import random_split

import matplotlib.pyplot as plt
from torchvision.utils import make_grid
import pandas as pd

#from Cuda import DeviceDataLoader

# %%
def loss_fn(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x, size_average=False)
    # BCE = F.mse_loss(recon_x, x, size_average=False)

    # see Appendix B from VAE paper:
    # Kingma and Welling. Auto-Encoding Variational Bayes. ICLR, 2014
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD = -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp())

    return BCE + KLD, BCE, KLD

# %%
torch.cuda.empty_cache() 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = 'cuda'
LEARNING_RATE = 1e-4
BATCH_SIZE = 64
IMAGE_SIZE = 28
CHANNELS_IMG = 1
Z_DIM = 100
NUM_EPOCHS = 5
IMAGE_CHANNELS = 1
RANK = 150
H_DIM = 200

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
# Download training dataset
dataset = MNIST(root='data/', download=True)
# MNIST dataset (images and labels)
dataset = MNIST(root='data/', train=True, transform=transforms.ToTensor())

# %%
dataset = datasets.FashionMNIST(root='data', train=True, download=True, transform=Compose([transforms.Resize(IMAGE_SIZE), ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %%
torch.manual_seed(0)

# %%
#train_ds, val_ds = random_split(dataset, [50000, 10000])

# %%
train_loader = DataLoader(dataset, BATCH_SIZE, shuffle=True)
#train_loader = DeviceDataLoader(train_loader, device)
#val_loader = DataLoader(val_ds, BATCH_SIZE)

# %%
#for images,_ in train_loader:
    #print(images[0])
    #break

# %%
model = VAE_CP_L3(IMAGE_SIZE*IMAGE_SIZE, H_DIM, Z_DIM, RANK).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
#model = DeviceDataLoader(model, device)

# %%
model.decoder[0].layer_U1.weight.shape
# Out:
# torch.Size([150, 200])

# %%
list_of_losses = []
list_of_epochs =[]
for epoch in range(NUM_EPOCHS):
    for images, _ in train_loader: 
        images = images.reshape(-1, IMAGE_SIZE*IMAGE_SIZE)   
        recon_images, mu, logvar = model(images.to(device))
        loss, bce, kld = loss_fn(recon_images.to(device), denorm(images).to(device), mu.to(device), logvar.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        #to_print = "Epoch[{}/{}] Loss: {:.3f} {:.3f} {:.3f}".format(epoch+1, 
                                #epochs, loss.data[0]/bs, bce.data[0]/bs, kld.data[0]/bs)
        #print(to_print)
    list_of_losses.append(loss)
    list_of_epochs.append(epoch + 1)
    print('loss', loss)
    print("Epoch : ", epoch + 1)
# Out:
# /home/ashish-razer/Programs/miniconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# loss tensor(7552.6870, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  1
# loss tensor(6236.1304, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  2
# loss tensor(7289.4136, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  3
# loss tensor(6226.9082, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  4
# loss tensor(6649.9033, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  5

# %%
for images, _ in train_loader: 
    recon_images, mu, logvar = model(images.to(device))
    break

# %%
recon_images = recon_images.reshape(-1, 1, IMAGE_SIZE, IMAGE_SIZE)

# %%
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(images.detach()[:nmax], nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
show_images(denorm(images))

# %%
show_images(recon_images.to('cpu'))

# %%
list_of_losses = [i.detach().numpy() for i in list_of_losses ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 list_of_losses = [i.detach().numpy() for i in list_of_losses ]
#
# Cell In[19], line 1, in <listcomp>(.0)
# ----> 1 list_of_losses = [i.detach().numpy() for i in list_of_losses ]
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
my_dict = {
    "epochs": list_of_epochs, 
    "losses": list_of_losses
}

df = pd.DataFrame(my_dict)

# %%
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_c99ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c99ca_level0_col0" class="col_heading level0 col0" >epochs</th>
#       <th id="T_c99ca_level0_col1" class="col_heading level0 col1" >losses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c99ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c99ca_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c99ca_row0_col1" class="data row0 col1" >1623.1459</td>
#     </tr>
#     <tr>
#       <th id="T_c99ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c99ca_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_c99ca_row1_col1" class="data row1 col1" >1243.1627</td>
#     </tr>
#     <tr>
#       <th id="T_c99ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c99ca_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_c99ca_row2_col1" class="data row2 col1" >1244.3336</td>
#     </tr>
#     <tr>
#       <th id="T_c99ca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c99ca_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_c99ca_row3_col1" class="data row3 col1" >1224.0966</td>
#     </tr>
#     <tr>
#       <th id="T_c99ca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c99ca_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_c99ca_row4_col1" class="data row4 col1" >1161.74</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_param = []
for name, param in model.named_parameters():
    num = torch.count_nonzero(param)
    num_param.append(num)

# %%
torch.sum(torch.tensor(num_param))
# Out:
# tensor(651784)
